# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

import nltk

# %%
import pandas as pd
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

from transformers import AutoTokenizer, AutoModelForSequenceClassification
from scipy.special import softmax

# ==============================
# Download NLTK resources
# ==============================
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('vader_lexicon')

# Read Excel file
df = pd.read_excel('/content/drive/MyDrive/dataset/Reviews.csv.xlsx')

print(df.shape)

# Take first 500 rows
df = df.head(500)

print(df.shape)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# (568454, 10)
# (500, 10)

# %%
print("Original Shape:", df.shape)
# Out:
# Original Shape: (500, 10)

# %%
print("Working Shape:", df.shape)
# Out:
# Working Shape: (500, 10)

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
ax = df['Score'].value_counts().sort_index() \
    .plot(kind='bar',
          title='Count of Reviews by Stars',
          figsize=(10, 5))
ax.set_xlabel('Review Stars')
plt.show()

# %%
example = df['Text'][50]
print(example)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')

sia = SentimentIntensityAnalyzer()

text = "This product is very good and the quality is amazing."

score = sia.polarity_scores(text)
print(score)
# Out:
# {'neg': 0.0, 'neu': 0.534, 'pos': 0.466, 'compound': 0.7902}
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
sia.polarity_scores('I am so happy!')
# Out:
# {'neg': 0.0, 'neu': 0.318, 'pos': 0.682, 'compound': 0.6468}

# %%
sia.polarity_scores('This is the worst thing ever.')

# %%
# Run the polarity score on the entire dataset
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row['Text']
    myid = row['Id']
    res[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={'index': 'Id'})
vaders = vaders.merge(df, how='left')

# %%
# Now we have sentiment score and metadata
vaders.head()
# Out:
#    Id    neg    neu    pos  compound   ProductId          UserId  \
# 0   1  0.000  0.695  0.305    0.9441  B001E4KFG0  A3SGXH7AUHU8GW
# 1   2  0.138  0.862  0.000   -0.5664  B00813GRG4  A1D87F6ZCVE5NK
# 2   3  0.091  0.754  0.155    0.8265  B000LQOCH0   ABXLMWJIXXAIN
# 3   4  0.000  1.000  0.000    0.0000  B000UA0QIQ  A395BORC6FGVXV
# 4   5  0.000  0.552  0.448    0.9468  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# 2  Natalia Corres "Natalia Corres"                     1
# 3                             Karl                     3
# 4    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# 2                       1      4  1219017600  "Delight" says it all
# 3                       3      2  1307923200         Cough Medicine
# 4                       0      5  1350777600            Great taffy
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...
# 3  If you are looking for the secret ingredient i...
# 4  Great taffy at a great price.  There was a wid...

# %%
#Plot VADER results
ax = sns.barplot(data=vaders, x='Score', y='compound')
ax.set_title('Compund Score by Amazon Star Review')
plt.show()

# %%
#vader result
fig, axs = plt.subplots(1, 3, figsize=(12, 3))
sns.barplot(data=vaders, x='Score', y='pos', ax=axs[0])
sns.barplot(data=vaders, x='Score', y='neu', ax=axs[1])
sns.barplot(data=vaders, x='Score', y='neg', ax=axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Neutral')
axs[2].set_title('Negative')
plt.tight_layout()
plt.show()

# %%
#Step 3. Roberta Pretrained Model
#Use a model trained of a large corpus of data.
#Transformer model accounts for the words but also the context related to other words

from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# RobertaForSequenceClassification LOAD REPORT from: cardiffnlp/twitter-roberta-base-sentiment
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
# VADER results on example
print(example)
sia.polarity_scores(example)
# Out:
# This product is very good and the quality is amazing.
# {'neg': 0.0, 'neu': 0.534, 'pos': 0.466, 'compound': 0.7902}

# %%
# Run for Roberta Model
encoded_text = tokenizer(example, return_tensors='pt')
output = model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
scores_dict = {
    'roberta_neg' : scores[0],
    'roberta_neu' : scores[1],
    'roberta_pos' : scores[2]
}
print(scores_dict)
# Out:
# {'roberta_neg': np.float32(0.0018957864), 'roberta_neu': np.float32(0.008524537), 'roberta_pos': np.float32(0.98957974)}

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()

res = {}

for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row['Text']
    myid = row['Id']
    res[myid] = sia.polarity_scores(text)

vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={'index': 'Id'})
vaders = vaders.merge(df, how='left')
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
results_df = pd.DataFrame(res).T
results_df = results_df.reset_index().rename(columns={'index': 'Id'})
results_df = results_df.merge(df, how='left')

# %%
# Compare Scores between models
results_df.columns
# Out:
# Index(['Id', 'neg', 'neu', 'pos', 'compound', 'ProductId', 'UserId',
#        'ProfileName', 'HelpfulnessNumerator', 'HelpfulnessDenominator',
#        'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
results = {}

for i, row in tqdm(df.iterrows(), total=len(df)):
    try:
        text = row['Text']
        myid = row['Id']

        vader_result = sia.polarity_scores(text)

        vader_result = {
            f'vader_{k}': v
            for k, v in vader_result.items()
        }

        roberta_result = polarity_scores_roberta(text)

        both = {**vader_result, **roberta_result}

        results[myid] = both

    except Exception as e:
        print(f"Error for ID {myid}: {e}")

results_df = pd.DataFrame(results).T
results_df = results_df.reset_index().rename(columns={'index': 'Id'})
results_df = results_df.merge(df, how='left')
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Error for ID 1: name 'polarity_scores_roberta' is not defined
# Error for ID 2: name 'polarity_scores_roberta' is not defined
# Error for ID 3: name 'polarity_scores_roberta' is not defined
# Error for ID 4: name 'polarity_scores_roberta' is not defined
# Error for ID 5: name 'polarity_scores_roberta' is not defined
# Error for ID 6: name 'polarity_scores_roberta' is not defined
# Error for ID 7: name 'polarity_scores_roberta' is not defined
# Error for ID 8: name 'polarity_scores_roberta' is not defined
# Error for ID 9: name 'polarity_scores_roberta' is not defined
# Error for ID 10: name 'polarity_scores_roberta' is not defined
# Error for ID 11: name 'polarity_scores_roberta' is not defined
# Error for ID 12: name 'polarity_scores_roberta' is not defined
# Error for ID 13: name 'polarity_scores_roberta' is not defined
# Error for ID 14: name 'polarity_scores_roberta' is not defined
# Error for ID 15: name 'polarity_scores_roberta' is not defined
# Error for ID 16: name 'polarity_scores_roberta' is not defined
# Error for ID 17: name 'polarity_scores_roberta' is not defined
# Error for ID 18: name 'polarity_scores_roberta' is not defined
# Error for ID 19: name 'polarity_scores_roberta' is not defined
# Error for ID 20: name 'polarity_scores_roberta' is not defined
# Error for ID 21: name 'polarity_scores_roberta' is not defined
# Error for ID 22: name 'polarity_scores_roberta' is not defined
# Error for ID 23: name 'polarity_scores_roberta' is not defined
# Error for ID 24: name 'polarity_scores_roberta' is not defined
# Error for ID 25: name 'polarity_scores_roberta' is not defined
# Error for ID 26: name 'polarity_scores_roberta' is not defined
# Error for ID 27: name 'polarity_scores_roberta' is not defined
# Error for ID 28: name 'polarity_scores_roberta' is not defined
# Error for ID 29: name 'polarity_scores_roberta' is not defined
# Error for ID 30: name 'polarity_scores_roberta' is not defined
# Error for ID 31: name 'polarity_scores_roberta' is not defined
# Error for ID 32: name 'polarity_scores_roberta' is not defined
# Error for ID 33: name 'polarity_scores_roberta' is not defined
# Error for ID 34: name 'polarity_scores_roberta' is not defined
# Error for ID 35: name 'polarity_scores_roberta' is not defined
# Error for ID 36: name 'polarity_scores_roberta' is not defined
# Error for ID 37: name 'polarity_scores_roberta' is not defined
# Error for ID 38: name 'polarity_scores_roberta' is not defined
# Error for ID 39: name 'polarity_scores_roberta' is not defined
# Error for ID 40: name 'polarity_scores_roberta' is not defined
# Error for ID 41: name 'polarity_scores_roberta' is not defined
# Error for ID 42: name 'polarity_scores_roberta' is not defined
# Error for ID 43: name 'polarity_scores_roberta' is not defined
# Error for ID 44: name 'polarity_scores_roberta' is not defined
# Error for ID 45: name 'polarity_scores_roberta' is not defined
# Error for ID 46: name 'polarity_scores_roberta' is not defined
# Error for ID 47: name 'polarity_scores_roberta' is not defined
# Error for ID 48: name 'polarity_scores_roberta' is not defined
# Error for ID 49: name 'polarity_scores_roberta' is not defined
# Error for ID 50: name 'polarity_scores_roberta' is not defined
# Error for ID 51: name 'polarity_scores_roberta' is not defined
# Error for ID 52: name 'polarity_scores_roberta' is not defined
# Error for ID 53: name 'polarity_scores_roberta' is not defined
# Error for ID 54: name 'polarity_scores_roberta' is not defined
# Error for ID 55: name 'polarity_scores_roberta' is not defined
# Error for ID 56: name 'polarity_scores_roberta' is not defined
# Error for ID 57: name 'polarity_scores_roberta' is not defined
# Error for ID 58: name 'polarity_scores_roberta' is not defined
# Error for ID 59: name 'polarity_scores_roberta' is not defined
# Error for ID 60: name 'polarity_scores_roberta' is not defined
# Error for ID 61: name 'polarity_scores_roberta' is not defined
# Error for ID 62: name 'polarity_scores_roberta' is not defined
# Error for ID 63: name 'polarity_scores_roberta' is not defined
# Error for ID 64: name 'polarity_scores_roberta' is not defined
# Error for ID 65: name 'polarity_scores_roberta' is not defined
# Error for ID 66: name 'polarity_scores_roberta' is not defined
# Error for ID 67: name 'polarity_scores_roberta' is not defined
# Error for ID 68: name 'polarity_scores_roberta' is not defined
# Error for ID 69: name 'polarity_scores_roberta' is not defined
# Error for ID 70: name 'polarity_scores_roberta' is not defined
# Error for ID 71: name 'polarity_scores_roberta' is not defined
# Error for ID 72: name 'polarity_scores_roberta' is not defined
# Error for ID 73: name 'polarity_scores_roberta' is not defined
# Error for ID 74: name 'polarity_scores_roberta' is not defined
# Error for ID 75: name 'polarity_scores_roberta' is not defined
# Error for ID 76: name 'polarity_scores_roberta' is not defined
# Error for ID 77: name 'polarity_scores_roberta' is not defined
# Error for ID 78: name 'polarity_scores_roberta' is not defined
# Error for ID 79: name 'polarity_scores_roberta' is not defined
# Error for ID 80: name 'polarity_scores_roberta' is not defined
# Error for ID 81: name 'polarity_scores_roberta' is not defined
# Error for ID 82: name 'polarity_scores_roberta' is not defined
# Error for ID 83: name 'polarity_scores_roberta' is not defined
# Error for ID 84: name 'polarity_scores_roberta' is not defined
# Error for ID 85: name 'polarity_scores_roberta' is not defined
# Error for ID 86: name 'polarity_scores_roberta' is not defined
# Error for ID 87: name 'polarity_scores_roberta' is not defined
# Error for ID 88: name 'polarity_scores_roberta' is not defined
# Error for ID 89: name 'polarity_scores_roberta' is not defined
# Error for ID 90: name 'polarity_scores_roberta' is not defined
# Error for ID 91: name 'polarity_scores_roberta' is not defined
# Error for ID 92: name 'polarity_scores_roberta' is not defined
# Error for ID 93: name 'polarity_scores_roberta' is not defined
# Error for ID 94: name 'polarity_scores_roberta' is not defined
# Error for ID 95: name 'polarity_scores_roberta' is not defined
# Error for ID 96: name 'polarity_scores_roberta' is not defined
# Error for ID 97: name 'polarity_scores_roberta' is not defined
# Error for ID 98: name 'polarity_scores_roberta' is not defined
# Error for ID 99: name 'polarity_scores_roberta' is not defined
# Error for ID 100: name 'polarity_scores_roberta' is not defined
# Error for ID 101: name 'polarity_scores_roberta' is not defined
# Error for ID 102: name 'polarity_scores_roberta' is not defined
# Error for ID 103: name 'polarity_scores_roberta' is not defined
# Error for ID 104: name 'polarity_scores_roberta' is not defined
# Error for ID 105: name 'polarity_scores_roberta' is not defined
# Error for ID 267: name 'polarity_scores_roberta' is not defined
# Error for ID 268: name 'polarity_scores_roberta' is not defined
# Error for ID 269: name 'polarity_scores_roberta' is not defined
# Error for ID 270: name 'polarity_scores_roberta' is not defined
# Error for ID 271: name 'polarity_scores_roberta' is not defined
# Error for ID 272: name 'polarity_scores_roberta' is not defined
# Error for ID 273: name 'polarity_scores_roberta' is not defined
# Error for ID 274: name 'polarity_scores_roberta' is not defined
# Error for ID 275: name 'polarity_scores_roberta' is not defined
# Error for ID 276: name 'polarity_scores_roberta' is not defined
# Error for ID 277: name 'polarity_scores_roberta' is not defined
# Error for ID 278: name 'polarity_scores_roberta' is not defined
# Error for ID 279: name 'polarity_scores_roberta' is not defined
# Error for ID 280: name 'polarity_scores_roberta' is not defined
# Error for ID 281: name 'polarity_scores_roberta' is not defined
# Error for ID 282: name 'polarity_scores_roberta' is not defined
# Error for ID 283: name 'polarity_scores_roberta' is not defined
# Error for ID 284: name 'polarity_scores_roberta' is not defined
# Error for ID 285: name 'polarity_scores_roberta' is not defined
# Error for ID 286: name 'polarity_scores_roberta' is not defined
# Error for ID 287: name 'polarity_scores_roberta' is not defined
# Error for ID 288: name 'polarity_scores_roberta' is not defined
# Error for ID 289: name 'polarity_scores_roberta' is not defined
# Error for ID 290: name 'polarity_scores_roberta' is not defined
# Error for ID 291: name 'polarity_scores_roberta' is not defined
# Error for ID 292: name 'polarity_scores_roberta' is not defined
# Error for ID 293: name 'polarity_scores_roberta' is not defined
# Error for ID 294: name 'polarity_scores_roberta' is not defined
# Error for ID 295: name 'polarity_scores_roberta' is not defined
# Error for ID 296: name 'polarity_scores_roberta' is not defined
# Error for ID 297: name 'polarity_scores_roberta' is not defined
# Error for ID 298: name 'polarity_scores_roberta' is not defined
# Error for ID 299: name 'polarity_scores_roberta' is not defined
# Error for ID 300: name 'polarity_scores_roberta' is not defined
# Error for ID 301: name 'polarity_scores_roberta' is not defined
# Error for ID 302: name 'polarity_scores_roberta' is not defined
# Error for ID 303: name 'polarity_scores_roberta' is not defined
# Error for ID 304: name 'polarity_scores_roberta' is not defined
# Error for ID 305: name 'polarity_scores_roberta' is not defined
# Error for ID 306: name 'polarity_scores_roberta' is not defined
# Error for ID 307: name 'polarity_scores_roberta' is not defined
# Error for ID 308: name 'polarity_scores_roberta' is not defined
# Error for ID 309: name 'polarity_scores_roberta' is not defined
# Error for ID 310: name 'polarity_scores_roberta' is not defined
# Error for ID 311: name 'polarity_scores_roberta' is not defined
# Error for ID 312: name 'polarity_scores_roberta' is not defined
# Error for ID 313: name 'polarity_scores_roberta' is not defined
# Error for ID 314: name 'polarity_scores_roberta' is not defined
# Error for ID 315: name 'polarity_scores_roberta' is not defined
# Error for ID 316: name 'polarity_scores_roberta' is not defined
# Error for ID 317: name 'polarity_scores_roberta' is not defined
# Error for ID 318: name 'polarity_scores_roberta' is not defined
# Error for ID 319: name 'polarity_scores_roberta' is not defined
# Error for ID 320: name 'polarity_scores_roberta' is not defined
# Error for ID 374: name 'polarity_scores_roberta' is not defined
# Error for ID 375: name 'polarity_scores_roberta' is not defined
# Error for ID 376: name 'polarity_scores_roberta' is not defined
# Error for ID 377: name 'polarity_scores_roberta' is not defined
# Error for ID 378: name 'polarity_scores_roberta' is not defined
# Error for ID 379: name 'polarity_scores_roberta' is not defined
# Error for ID 380: name 'polarity_scores_roberta' is not defined
# Error for ID 381: name 'polarity_scores_roberta' is not defined
# Error for ID 382: name 'polarity_scores_roberta' is not defined
# Error for ID 383: name 'polarity_scores_roberta' is not defined
# Error for ID 384: name 'polarity_scores_roberta' is not defined
# Error for ID 385: name 'polarity_scores_roberta' is not defined
# Error for ID 386: name 'polarity_scores_roberta' is not defined
# Error for ID 387: name 'polarity_scores_roberta' is not defined
# Error for ID 388: name 'polarity_scores_roberta' is not defined
# Error for ID 389: name 'polarity_scores_roberta' is not defined
# Error for ID 390: name 'polarity_scores_roberta' is not defined
# Error for ID 391: name 'polarity_scores_roberta' is not defined
# Error for ID 392: name 'polarity_scores_roberta' is not defined
# Error for ID 393: name 'polarity_scores_roberta' is not defined
# Error for ID 394: name 'polarity_scores_roberta' is not defined
# Error for ID 395: name 'polarity_scores_roberta' is not defined
# Error for ID 396: name 'polarity_scores_roberta' is not defined
# Error for ID 397: name 'polarity_scores_roberta' is not defined
# Error for ID 398: name 'polarity_scores_roberta' is not defined
# Error for ID 399: name 'polarity_scores_roberta' is not defined
# Error for ID 400: name 'polarity_scores_roberta' is not defined
# Error for ID 401: name 'polarity_scores_roberta' is not defined
# Error for ID 402: name 'polarity_scores_roberta' is not defined
# Error for ID 403: name 'polarity_scores_roberta' is not defined
# Error for ID 404: name 'polarity_scores_roberta' is not defined
# Error for ID 405: name 'polarity_scores_roberta' is not defined
# Error for ID 406: name 'polarity_scores_roberta' is not defined
# Error for ID 407: name 'polarity_scores_roberta' is not defined
# Error for ID 408: name 'polarity_scores_roberta' is not defined
# Error for ID 409: name 'polarity_scores_roberta' is not defined
# Error for ID 410: name 'polarity_scores_roberta' is not defined
# Error for ID 411: name 'polarity_scores_roberta' is not defined
# Error for ID 412: name 'polarity_scores_roberta' is not defined
# Error for ID 413: name 'polarity_scores_roberta' is not defined
# Error for ID 414: name 'polarity_scores_roberta' is not defined
# Error for ID 415: name 'polarity_scores_roberta' is not defined
# Error for ID 416: name 'polarity_scores_roberta' is not defined
# Error for ID 417: name 'polarity_scores_roberta' is not defined
# Error for ID 418: name 'polarity_scores_roberta' is not defined
# Error for ID 419: name 'polarity_scores_roberta' is not defined
# Error for ID 420: name 'polarity_scores_roberta' is not defined
# Error for ID 421: name 'polarity_scores_roberta' is not defined
# Error for ID 422: name 'polarity_scores_roberta' is not defined
# Error for ID 423: name 'polarity_scores_roberta' is not defined
# Error for ID 424: name 'polarity_scores_roberta' is not defined
# Error for ID 425: name 'polarity_scores_roberta' is not defined
# Error for ID 426: name 'polarity_scores_roberta' is not defined
# Error for ID 427: name 'polarity_scores_roberta' is not defined
# Error for ID 428: name 'polarity_scores_roberta' is not defined
# Error for ID 429: name 'polarity_scores_roberta' is not defined
# Error for ID 430: name 'polarity_scores_roberta' is not defined
# Error for ID 431: name 'polarity_scores_roberta' is not defined
# Error for ID 432: name 'polarity_scores_roberta' is not defined
# Error for ID 433: name 'polarity_scores_roberta' is not defined
# Error for ID 434: name 'polarity_scores_roberta' is not defined
# Error for ID 435: name 'polarity_scores_roberta' is not defined
# Error for ID 436: name 'polarity_scores_roberta' is not defined
# Error for ID 437: name 'polarity_scores_roberta' is not defined
# Error for ID 438: name 'polarity_scores_roberta' is not defined
# Error for ID 439: name 'polarity_scores_roberta' is not defined
# Error for ID 440: name 'polarity_scores_roberta' is not defined
# Error for ID 441: name 'polarity_scores_roberta' is not defined
# Error for ID 442: name 'polarity_scores_roberta' is not defined
# Error for ID 443: name 'polarity_scores_roberta' is not defined
# Error for ID 444: name 'polarity_scores_roberta' is not defined
# Error for ID 445: name 'polarity_scores_roberta' is not defined
# Error for ID 446: name 'polarity_scores_roberta' is not defined
# Error for ID 447: name 'polarity_scores_roberta' is not defined
# Error for ID 448: name 'polarity_scores_roberta' is not defined
# Error for ID 449: name 'polarity_scores_roberta' is not defined
# Error for ID 450: name 'polarity_scores_roberta' is not defined
# Error for ID 451: name 'polarity_scores_roberta' is not defined
# Error for ID 452: name 'polarity_scores_roberta' is not defined
# Error for ID 453: name 'polarity_scores_roberta' is not defined
# Error for ID 454: name 'polarity_scores_roberta' is not defined
# Error for ID 455: name 'polarity_scores_roberta' is not defined
# Error for ID 456: name 'polarity_scores_roberta' is not defined
# Error for ID 457: name 'polarity_scores_roberta' is not defined
# Error for ID 458: name 'polarity_scores_roberta' is not defined
# Error for ID 459: name 'polarity_scores_roberta' is not defined
# Error for ID 460: name 'polarity_scores_roberta' is not defined
# Error for ID 461: name 'polarity_scores_roberta' is not defined
# Error for ID 462: name 'polarity_scores_roberta' is not defined
# Error for ID 463: name 'polarity_scores_roberta' is not defined
# Error for ID 464: name 'polarity_scores_roberta' is not defined
# Error for ID 465: name 'polarity_scores_roberta' is not defined
# Error for ID 466: name 'polarity_scores_roberta' is not defined
# Error for ID 467: name 'polarity_scores_roberta' is not defined
# Error for ID 468: name 'polarity_scores_roberta' is not defined
# Error for ID 469: name 'polarity_scores_roberta' is not defined
# Error for ID 470: name 'polarity_scores_roberta' is not defined
# Error for ID 471: name 'polarity_scores_roberta' is not defined
# Error for ID 472: name 'polarity_scores_roberta' is not defined
# Error for ID 473: name 'polarity_scores_roberta' is not defined
# Error for ID 474: name 'polarity_scores_roberta' is not defined
# Error for ID 475: name 'polarity_scores_roberta' is not defined
# Error for ID 476: name 'polarity_scores_roberta' is not defined
# Error for ID 477: name 'polarity_scores_roberta' is not defined
# Error for ID 478: name 'polarity_scores_roberta' is not defined
# Error for ID 479: name 'polarity_scores_roberta' is not defined
# Error for ID 480: name 'polarity_scores_roberta' is not defined
# Error for ID 481: name 'polarity_scores_roberta' is not defined
# Error for ID 482: name 'polarity_scores_roberta' is not defined
# Error for ID 483: name 'polarity_scores_roberta' is not defined
# Error for ID 484: name 'polarity_scores_roberta' is not defined
# Error for ID 485: name 'polarity_scores_roberta' is not defined
# Error for ID 486: name 'polarity_scores_roberta' is not defined
# Error for ID 487: name 'polarity_scores_roberta' is not defined
# Error for ID 488: name 'polarity_scores_roberta' is not defined
# Error for ID 489: name 'polarity_scores_roberta' is not defined
# Error for ID 490: name 'polarity_scores_roberta' is not defined
# Error for ID 491: name 'polarity_scores_roberta' is not defined
# Error for ID 492: name 'polarity_scores_roberta' is not defined
# Error for ID 493: name 'polarity_scores_roberta' is not defined
# Error for ID 494: name 'polarity_scores_roberta' is not defined
# Error for ID 495: name 'polarity_scores_roberta' is not defined
# Error for ID 496: name 'polarity_scores_roberta' is not defined
# Error for ID 497: name 'polarity_scores_roberta' is not defined
# Error for ID 498: name 'polarity_scores_roberta' is not defined
# Error for ID 499: name 'polarity_scores_roberta' is not defined
# Error for ID 500: name 'polarity_scores_roberta' is not defined

# %%
print(results_df.columns)
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
# ==============================
# Imports
# ==============================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk

from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

# ==============================
# Download VADER Lexicon
# ==============================
nltk.download('vader_lexicon')

# ==============================
# Initialize VADER
# ==============================
sia = SentimentIntensityAnalyzer()

# ==============================
# Generate Sentiment Scores
# ==============================
res = {}

for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row['Text']
    myid = row['Id']
    res[myid] = sia.polarity_scores(text)

# ==============================
# Create Results DataFrame
# ==============================
results_df = pd.DataFrame(res).T
results_df = results_df.reset_index()
results_df = results_df.rename(columns={'index': 'Id'})

# Merge with original dataframe
results_df = results_df.merge(df, on='Id')

# ==============================
# Check Columns
# ==============================
print(results_df.columns)

# ==============================
# Pair Plot
# ==============================
sns.pairplot(
    data=results_df,
    vars=['neg', 'neu', 'pos'],
    hue='Score',
    palette='tab10'
)

plt.show()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#   0%|          | 0/500 [00:00<?, ?it/s]
# Index(['Id', 'neg', 'neu', 'pos', 'compound', 'ProductId', 'UserId',
#        'ProfileName', 'HelpfulnessNumerator', 'HelpfulnessDenominator',
#        'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
print("df exists:", 'df' in globals())
# Out:
# df exists: False

# %%
# Read Excel file
import pandas as pd
df = pd.read_excel('/content/drive/MyDrive/dataset/Reviews.csv.xlsx')

# %%
print(df.shape)
df.head()
# Out:
# (568454, 10)
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
# Import required libraries
import pandas as pd
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

# Download VADER sentiment lexicon (only needed once)
nltk.download('vader_lexicon')

# Initialize VADER Sentiment Analyzer
sia = SentimentIntensityAnalyzer()

# Create an empty dictionary to store sentiment scores
res = {}

# Loop through each review in the dataset
for i, row in tqdm(df.iterrows(), total=len(df)):

    # Extract review text
    text = row['Text']

    # Extract review ID
    myid = row['Id']

    # Calculate sentiment scores (negative, neutral, positive, compound)
    res[myid] = sia.polarity_scores(text)

# Convert sentiment score dictionary into a DataFrame
results_df = pd.DataFrame(res).T

# Move review IDs from index to a column
results_df = results_df.reset_index()

# Rename the index column to 'Id'
results_df = results_df.rename(columns={'index': 'Id'})

# Merge sentiment scores with the original dataset
results_df = results_df.merge(df, on='Id')

# Display first 5 rows of the final DataFrame
print(results_df.head())
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#   0%|          | 0/568454 [00:00<?, ?it/s]
#    Id    neg    neu    pos  compound   ProductId          UserId  \
# 0   1  0.000  0.695  0.305    0.9441  B001E4KFG0  A3SGXH7AUHU8GW
# 1   2  0.138  0.862  0.000   -0.5664  B00813GRG4  A1D87F6ZCVE5NK
# 2   3  0.091  0.754  0.155    0.8265  B000LQOCH0   ABXLMWJIXXAIN
# 3   4  0.000  1.000  0.000    0.0000  B000UA0QIQ  A395BORC6FGVXV
# 4   5  0.000  0.552  0.448    0.9468  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# 2  Natalia Corres "Natalia Corres"                     1
# 3                             Karl                     3
# 4    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# 2                       1      4  1219017600  "Delight" says it all
# 3                       3      2  1307923200         Cough Medicine
# 4                       0      5  1350777600            Great taffy
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...
# 3  If you are looking for the secret ingredient i...
# 4  Great taffy at a great price.  There was a wid...

# %%
print(results_df.columns.tolist())
# Out:
# ['Id', 'neg', 'neu', 'pos', 'compound', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator', 'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text']

# %%
vaders = pd.DataFrame(res).T

# %%
print(results_df.columns)
# Out:
# Index(['Id', 'neg', 'neu', 'pos', 'compound', 'ProductId', 'UserId',
#        'ProfileName', 'HelpfulnessNumerator', 'HelpfulnessDenominator',
#        'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
results_df.query('Score == 1') \
    .sort_values('pos', ascending=False)['Text'].iloc[0]
# Out:
# 'Quality of product is excellent, cost is excellent and delivery is superb.  Very satisfied.'

# %%
print(results_df.columns.tolist())
results_df.query('Score == 1') \
    .sort_values('pos', ascending=False)['Text'].values[0]
# Out:
# ['Id', 'neg', 'neu', 'pos', 'compound', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator', 'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text']
# 'Quality of product is excellent, cost is excellent and delivery is superb.  Very satisfied.'
